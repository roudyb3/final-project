# %%
import pandas as pd
from datetime import datetime, timedelta
import numpy as np

# %%
nba_seasons = "Seasons_Stats.csv"
nba_seasons_df = pd.read_csv(nba_seasons, encoding = "utf-8")

# %%
nba_seasons_df.head()
# Out:
#    Unnamed: 0    Year           Player  Pos   Age   Tm     G  GS  MP  PER  \
# 0           0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN
# 1           1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN
# 2           2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN
# 3           3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN
# 4           4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN
#
#    ...    FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  ...  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  ...  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  ...  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  ...  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  ...  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 53 columns]

# %%
nba_seasons_df = nba_seasons_df[(nba_seasons_df['Year'] > 2009.0)]

# %%
nba_seasons_df = nba_seasons_df[(nba_seasons_df['Year'] < 2020.0)]

# %%
nba_seasons_df.head()
# Out:
#        Unnamed: 0    Year             Player Pos   Age   Tm     G    GS  \
# 19922       19922  2010.0      Arron Afflalo  SG  24.0  DEN  82.0  75.0
# 19923       19923  2010.0      Alexis Ajinca   C  21.0  CHA   6.0   0.0
# 19924       19924  2010.0  LaMarcus Aldridge  PF  24.0  POR  78.0  78.0
# 19925       19925  2010.0      Joe Alexander  SF  23.0  CHI   8.0   0.0
# 19926       19926  2010.0        Malik Allen  PF  31.0  DEN  51.0   3.0
#
#            MP   PER  ...    FT%    ORB    DRB    TRB    AST   STL   BLK  \
# 19922  2221.0  10.9  ...  0.735   59.0  193.0  252.0  138.0  46.0  30.0
# 19923    30.0   6.3  ...  0.000    1.0    3.0    4.0    0.0   1.0   1.0
# 19924  2922.0  18.2  ...  0.757  192.0  435.0  627.0  160.0  67.0  48.0
# 19925    29.0   2.8  ...  0.667    2.0    3.0    5.0    2.0   1.0   1.0
# 19926   456.0   5.9  ...  0.923   36.0   46.0   82.0   16.0  11.0   5.0
#
#          TOV     PF     PTS
# 19922   74.0  225.0   724.0
# 19923    2.0    5.0    10.0
# ...

# %%
nba_seasons_df = nba_seasons_df.drop(columns = ['Unnamed: 0'])
nba_seasons_df.head()
# Out:
#          Year             Player Pos   Age   Tm     G    GS      MP   PER  \
# 19922  2010.0      Arron Afflalo  SG  24.0  DEN  82.0  75.0  2221.0  10.9
# 19923  2010.0      Alexis Ajinca   C  21.0  CHA   6.0   0.0    30.0   6.3
# 19924  2010.0  LaMarcus Aldridge  PF  24.0  POR  78.0  78.0  2922.0  18.2
# 19925  2010.0      Joe Alexander  SF  23.0  CHI   8.0   0.0    29.0   2.8
# 19926  2010.0        Malik Allen  PF  31.0  DEN  51.0   3.0   456.0   5.9
#
#          TS%  ...    FT%    ORB    DRB    TRB    AST   STL   BLK    TOV  \
# 19922  0.576  ...  0.735   59.0  193.0  252.0  138.0  46.0  30.0   74.0
# 19923  0.479  ...  0.000    1.0    3.0    4.0    0.0   1.0   1.0    2.0
# 19924  0.535  ...  0.757  192.0  435.0  627.0  160.0  67.0  48.0  104.0
# 19925  0.273  ...  0.667    2.0    3.0    5.0    2.0   1.0   1.0    0.0
# 19926  0.431  ...  0.923   36.0   46.0   82.0   16.0  11.0   5.0   22.0
#
#           PF     PTS
# 19922  225.0   724.0
# 19923    5.0    10.0
# ...

# %%
nba_seasons_df
# Out:
#          Year             Player Pos   Age   Tm     G    GS      MP   PER  \
# 19922  2010.0      Arron Afflalo  SG  24.0  DEN  82.0  75.0  2221.0  10.9
# 19923  2010.0      Alexis Ajinca   C  21.0  CHA   6.0   0.0    30.0   6.3
# 19924  2010.0  LaMarcus Aldridge  PF  24.0  POR  78.0  78.0  2922.0  18.2
# 19925  2010.0      Joe Alexander  SF  23.0  CHI   8.0   0.0    29.0   2.8
# 19926  2010.0        Malik Allen  PF  31.0  DEN  51.0   3.0   456.0   5.9
# ...       ...                ...  ..   ...  ...   ...   ...     ...   ...
# 24686  2017.0        Cody Zeller  PF  24.0  CHO  62.0  58.0  1725.0  16.7
# 24687  2017.0       Tyler Zeller   C  27.0  BOS  51.0   5.0   525.0  13.0
# 24688  2017.0  Stephen Zimmerman   C  20.0  ORL  19.0   0.0   108.0   7.3
# 24689  2017.0        Paul Zipser  SF  22.0  CHI  44.0  18.0   843.0   6.9
# 24690  2017.0        Ivica Zubac   C  19.0  LAL  38.0  11.0   609.0  17.0
#
#          TS%  ...    FT%    ORB    DRB    TRB    AST   STL   BLK    TOV  \
# ...

# %%
nba_seasons_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4762 entries, 19922 to 24690
# Data columns (total 52 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    4762 non-null   float64
#  1   Player  4762 non-null   object
#  2   Pos     4762 non-null   object
#  3   Age     4762 non-null   float64
#  4   Tm      4762 non-null   object
#  5   G       4762 non-null   float64
#  6   GS      4762 non-null   float64
#  7   MP      4762 non-null   float64
#  8   PER     4760 non-null   float64
#  9   TS%     4738 non-null   float64
#  10  3PAr    4738 non-null   float64
#  11  FTr     4738 non-null   float64
#  12  ORB%    4760 non-null   float64
#  13  DRB%    4760 non-null   float64
#  14  TRB%    4760 non-null   float64
#  15  AST%    4760 non-null   float64
#  16  STL%    4760 non-null   float64
#  17  BLK%    4760 non-null   float64
#  18  TOV%    4743 non-null   float64
#  19  USG%    4760 non-null   float64
# ...

# %%
nba_seasons_df['Year'] = pd.to_datetime(nba_seasons_df['Year'], format = '%Y')
nba_seasons_df.head()
# Out:
#             Year             Player Pos   Age   Tm     G    GS      MP   PER  \
# 19922 2010-01-01      Arron Afflalo  SG  24.0  DEN  82.0  75.0  2221.0  10.9
# 19923 2010-01-01      Alexis Ajinca   C  21.0  CHA   6.0   0.0    30.0   6.3
# 19924 2010-01-01  LaMarcus Aldridge  PF  24.0  POR  78.0  78.0  2922.0  18.2
# 19925 2010-01-01      Joe Alexander  SF  23.0  CHI   8.0   0.0    29.0   2.8
# 19926 2010-01-01        Malik Allen  PF  31.0  DEN  51.0   3.0   456.0   5.9
#
#          TS%  ...    FT%    ORB    DRB    TRB    AST   STL   BLK    TOV  \
# 19922  0.576  ...  0.735   59.0  193.0  252.0  138.0  46.0  30.0   74.0
# 19923  0.479  ...  0.000    1.0    3.0    4.0    0.0   1.0   1.0    2.0
# 19924  0.535  ...  0.757  192.0  435.0  627.0  160.0  67.0  48.0  104.0
# 19925  0.273  ...  0.667    2.0    3.0    5.0    2.0   1.0   1.0    0.0
# 19926  0.431  ...  0.923   36.0   46.0   82.0   16.0  11.0   5.0   22.0
#
#           PF     PTS
# 19922  225.0   724.0
# 19923    5.0    10.0
# ...

# %%
nba_seasons_df['Year'] = nba_seasons_df['Year'] - pd.offsets.DateOffset(years=1)
nba_seasons_df.head()
# Out:
#             Year             Player Pos   Age   Tm     G    GS      MP   PER  \
# 19922 2009-01-01      Arron Afflalo  SG  24.0  DEN  82.0  75.0  2221.0  10.9
# 19923 2009-01-01      Alexis Ajinca   C  21.0  CHA   6.0   0.0    30.0   6.3
# 19924 2009-01-01  LaMarcus Aldridge  PF  24.0  POR  78.0  78.0  2922.0  18.2
# 19925 2009-01-01      Joe Alexander  SF  23.0  CHI   8.0   0.0    29.0   2.8
# 19926 2009-01-01        Malik Allen  PF  31.0  DEN  51.0   3.0   456.0   5.9
#
#          TS%  ...    FT%    ORB    DRB    TRB    AST   STL   BLK    TOV  \
# 19922  0.576  ...  0.735   59.0  193.0  252.0  138.0  46.0  30.0   74.0
# 19923  0.479  ...  0.000    1.0    3.0    4.0    0.0   1.0   1.0    2.0
# 19924  0.535  ...  0.757  192.0  435.0  627.0  160.0  67.0  48.0  104.0
# 19925  0.273  ...  0.667    2.0    3.0    5.0    2.0   1.0   1.0    0.0
# 19926  0.431  ...  0.923   36.0   46.0   82.0   16.0  11.0   5.0   22.0
#
#           PF     PTS
# 19922  225.0   724.0
# 19923    5.0    10.0
# ...

# %%
nba_seasons_df['Season'] = nba_seasons_df['Year'].dt.year
nba_seasons_df.head()
# Out:
#             Year             Player Pos   Age   Tm     G    GS      MP   PER  \
# 19922 2009-01-01      Arron Afflalo  SG  24.0  DEN  82.0  75.0  2221.0  10.9
# 19923 2009-01-01      Alexis Ajinca   C  21.0  CHA   6.0   0.0    30.0   6.3
# 19924 2009-01-01  LaMarcus Aldridge  PF  24.0  POR  78.0  78.0  2922.0  18.2
# 19925 2009-01-01      Joe Alexander  SF  23.0  CHI   8.0   0.0    29.0   2.8
# 19926 2009-01-01        Malik Allen  PF  31.0  DEN  51.0   3.0   456.0   5.9
#
#          TS%  ...    ORB    DRB    TRB    AST   STL   BLK    TOV     PF  \
# 19922  0.576  ...   59.0  193.0  252.0  138.0  46.0  30.0   74.0  225.0
# 19923  0.479  ...    1.0    3.0    4.0    0.0   1.0   1.0    2.0    5.0
# 19924  0.535  ...  192.0  435.0  627.0  160.0  67.0  48.0  104.0  231.0
# 19925  0.273  ...    2.0    3.0    5.0    2.0   1.0   1.0    0.0    9.0
# 19926  0.431  ...   36.0   46.0   82.0   16.0  11.0   5.0   22.0   68.0
#
#           PTS  Season
# 19922   724.0    2009
# 19923    10.0    2009
# ...

# %%
#make the df easier to type
df = nba_seasons_df

# %%
#ppg 
df['PPG'] = df['PTS'].div(df['G'].values)
df['RPG'] = df['TRB'].div(df['G'].values)
df['APG'] = df['AST'].div(df['G'].values)
df['SPG'] = df['STL'].div(df['G'].values)
df['BPG'] = df['BLK'].div(df['G'].values)
df['TOPG'] = df['TOV'].div(df['G'].values)
df['PFPG'] = df['PF'].div(df['G'].values)
df['MPG'] = df['MP'].div(df['G'].values)
df.head()
# Out:
#             Year             Player Pos   Age   Tm     G    GS      MP   PER  \
# 19922 2009-01-01      Arron Afflalo  SG  24.0  DEN  82.0  75.0  2221.0  10.9
# 19923 2009-01-01      Alexis Ajinca   C  21.0  CHA   6.0   0.0    30.0   6.3
# 19924 2009-01-01  LaMarcus Aldridge  PF  24.0  POR  78.0  78.0  2922.0  18.2
# 19925 2009-01-01      Joe Alexander  SF  23.0  CHI   8.0   0.0    29.0   2.8
# 19926 2009-01-01        Malik Allen  PF  31.0  DEN  51.0   3.0   456.0   5.9
#
#          TS%  ...     PTS  Season        PPG       RPG       APG       SPG  \
# 19922  0.576  ...   724.0    2009   8.829268  3.073171  1.682927  0.560976
# 19923  0.479  ...    10.0    2009   1.666667  0.666667  0.000000  0.166667
# 19924  0.535  ...  1393.0    2009  17.858974  8.038462  2.051282  0.858974
# 19925  0.273  ...     4.0    2009   0.500000  0.625000  0.250000  0.125000
# 19926  0.431  ...   105.0    2009   2.058824  1.607843  0.313725  0.215686
#
#             BPG      TOPG      PFPG        MPG
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4762 entries, 19922 to 24690
# Data columns (total 61 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    4762 non-null   datetime64[ns]
#  1   Player  4762 non-null   object
#  2   Pos     4762 non-null   object
#  3   Age     4762 non-null   float64
#  4   Tm      4762 non-null   object
#  5   G       4762 non-null   float64
#  6   GS      4762 non-null   float64
#  7   MP      4762 non-null   float64
#  8   PER     4760 non-null   float64
#  9   TS%     4738 non-null   float64
#  10  3PAr    4738 non-null   float64
#  11  FTr     4738 non-null   float64
#  12  ORB%    4760 non-null   float64
#  13  DRB%    4760 non-null   float64
#  14  TRB%    4760 non-null   float64
#  15  AST%    4760 non-null   float64
#  16  STL%    4760 non-null   float64
#  17  BLK%    4760 non-null   float64
#  18  TOV%    4743 non-null   float64
#  19  USG%    4760 non-null   float64
# ...

# %%
df = df[['Season', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MPG', 'PPG', 'RPG', 'APG', 'SPG', 'BPG', 'TOPG', 'eFG%','FG', 'FGA', 'FG%','3P', '3PA','3P%','FT','FTA','FT%', 'PFPG','PER','TS%','USG%','OWS','DWS','WS','WS/48','OBPM','DBPM','BPM','VORP']]
df.head()
# Out:
#        Season             Player Pos   Age   Tm     G    GS        MPG  \
# 19922    2009      Arron Afflalo  SG  24.0  DEN  82.0  75.0  27.085366
# 19923    2009      Alexis Ajinca   C  21.0  CHA   6.0   0.0   5.000000
# 19924    2009  LaMarcus Aldridge  PF  24.0  POR  78.0  78.0  37.461538
# 19925    2009      Joe Alexander  SF  23.0  CHI   8.0   0.0   3.625000
# 19926    2009        Malik Allen  PF  31.0  DEN  51.0   3.0   8.941176
#
#              PPG       RPG  ...    TS%  USG%  OWS  DWS   WS  WS/48  OBPM  \
# 19922   8.829268  3.073171  ...  0.576  14.0  2.8  1.4  4.3  0.092   0.8
# 19923   1.666667  0.666667  ...  0.479  19.3 -0.1  0.0  0.0 -0.013  -8.5
# 19924  17.858974  8.038462  ...  0.535  22.9  5.5  3.3  8.8  0.145   0.9
# 19925   0.500000  0.625000  ...  0.273  11.3  0.0  0.0  0.0  0.030  -5.2
# 19926   2.058824  1.607843  ...  0.431  14.0 -0.3  0.3  0.1  0.009  -4.2
#
#        DBPM   BPM  VORP
# 19922  -0.5   0.3   1.3
# 19923  -2.0 -10.4  -0.1
# ...

# %%
df
# Out:
#        Season             Player Pos   Age   Tm     G    GS        MPG  \
# 19922    2009      Arron Afflalo  SG  24.0  DEN  82.0  75.0  27.085366
# 19923    2009      Alexis Ajinca   C  21.0  CHA   6.0   0.0   5.000000
# 19924    2009  LaMarcus Aldridge  PF  24.0  POR  78.0  78.0  37.461538
# 19925    2009      Joe Alexander  SF  23.0  CHI   8.0   0.0   3.625000
# 19926    2009        Malik Allen  PF  31.0  DEN  51.0   3.0   8.941176
# ...       ...                ...  ..   ...  ...   ...   ...        ...
# 24686    2016        Cody Zeller  PF  24.0  CHO  62.0  58.0  27.822581
# 24687    2016       Tyler Zeller   C  27.0  BOS  51.0   5.0  10.294118
# 24688    2016  Stephen Zimmerman   C  20.0  ORL  19.0   0.0   5.684211
# 24689    2016        Paul Zipser  SF  22.0  CHI  44.0  18.0  19.159091
# 24690    2016        Ivica Zubac   C  19.0  LAL  38.0  11.0  16.026316
#
#              PPG       RPG  ...    TS%  USG%  OWS  DWS   WS  WS/48  OBPM  \
# ...

# %%
df['Season'].unique()
# Out:
# array([2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4762 entries, 19922 to 24690
# Data columns (total 36 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Season  4762 non-null   int64
#  1   Player  4762 non-null   object
#  2   Pos     4762 non-null   object
#  3   Age     4762 non-null   float64
#  4   Tm      4762 non-null   object
#  5   G       4762 non-null   float64
#  6   GS      4762 non-null   float64
#  7   MPG     4762 non-null   float64
#  8   PPG     4762 non-null   float64
#  9   RPG     4762 non-null   float64
#  10  APG     4762 non-null   float64
#  11  SPG     4762 non-null   float64
#  12  BPG     4762 non-null   float64
#  13  TOPG    4762 non-null   float64
#  14  eFG%    4738 non-null   float64
#  15  FG      4762 non-null   float64
#  16  FGA     4762 non-null   float64
#  17  FG%     4738 non-null   float64
#  18  3P      4762 non-null   float64
#  19  3PA     4762 non-null   float64
# ...

# %%
seventeen = "2017.csv"
seventeen_df = pd.read_csv(seventeen, encoding = "utf-8")

# %%
#seventeen_df.head()

# %%
eighteen = "2018.csv"
eighteen_df = pd.read_csv(eighteen, encoding = "utf-8")

# %%
#eighteen_df.head()

# %%
frames = [df, seventeen_df, eighteen_df]
df_clean = pd.concat(frames)

# %%
df_clean
# Out:
#        Season             Player Pos   Age   Tm     G    GS        MPG  \
# 19922    2009      Arron Afflalo  SG  24.0  DEN  82.0  75.0  27.085366
# 19923    2009      Alexis Ajinca   C  21.0  CHA   6.0   0.0   5.000000
# 19924    2009  LaMarcus Aldridge  PF  24.0  POR  78.0  78.0  37.461538
# 19925    2009      Joe Alexander  SF  23.0  CHI   8.0   0.0   3.625000
# 19926    2009        Malik Allen  PF  31.0  DEN  51.0   3.0   8.941176
# ...       ...                ...  ..   ...  ...   ...   ...        ...
# 703      2018       Tyler Zeller   C  29.0  MEM   4.0   1.0  20.500000
# 704      2018         Ante Žižić   C  22.0  CLE  59.0  25.0  18.300000
# 705      2018        Ivica Zubac   C  21.0  TOT  59.0  37.0  17.600000
# 706      2018        Ivica Zubac   C  21.0  LAL  33.0  12.0  15.600000
# 707      2018        Ivica Zubac   C  21.0  LAC  26.0  25.0  20.200000
#
#              PPG       RPG  ...    TS%  USG%  OWS  DWS   WS  WS/48  OBPM  \
# ...

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6134 entries, 19922 to 707
# Data columns (total 36 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Season  6134 non-null   int64
#  1   Player  6134 non-null   object
#  2   Pos     6134 non-null   object
#  3   Age     6134 non-null   float64
#  4   Tm      6134 non-null   object
#  5   G       6134 non-null   float64
#  6   GS      6134 non-null   float64
#  7   MPG     6134 non-null   float64
#  8   PPG     6134 non-null   float64
#  9   RPG     6134 non-null   float64
#  10  APG     6134 non-null   float64
#  11  SPG     6134 non-null   float64
#  12  BPG     6134 non-null   float64
#  13  TOPG    6134 non-null   float64
#  14  eFG%    6100 non-null   float64
#  15  FG      6134 non-null   float64
#  16  FGA     6134 non-null   float64
#  17  FG%     6100 non-null   float64
#  18  3P      6134 non-null   float64
#  19  3PA     6134 non-null   float64
# ...

# %%
df_clean = df_clean.fillna(value=0, axis=None, inplace=False, limit=None, downcast=None)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6134 entries, 19922 to 707
# Data columns (total 36 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Season  6134 non-null   int64
#  1   Player  6134 non-null   object
#  2   Pos     6134 non-null   object
#  3   Age     6134 non-null   float64
#  4   Tm      6134 non-null   object
#  5   G       6134 non-null   float64
#  6   GS      6134 non-null   float64
#  7   MPG     6134 non-null   float64
#  8   PPG     6134 non-null   float64
#  9   RPG     6134 non-null   float64
#  10  APG     6134 non-null   float64
#  11  SPG     6134 non-null   float64
#  12  BPG     6134 non-null   float64
#  13  TOPG    6134 non-null   float64
#  14  eFG%    6134 non-null   float64
#  15  FG      6134 non-null   float64
#  16  FGA     6134 non-null   float64
#  17  FG%     6134 non-null   float64
#  18  3P      6134 non-null   float64
#  19  3PA     6134 non-null   float64
# ...

# %%
df_clean.to_csv ('seasons_clean.csv', index = False, header = True)
